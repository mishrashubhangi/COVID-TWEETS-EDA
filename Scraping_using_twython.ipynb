# %% [markdown]
# ##### Installing twython package

# %%
! pip install twython
# Out:
# Requirement already satisfied: twython in /usr/local/lib/python3.6/dist-packages (3.8.2)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from twython) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.1.0->twython) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.4.0->twython) (3.1.0)

# %%
import time
start = time.time() # Start time

# %%
from twython import Twython, TwythonError

app_key = "hg61RJTHj7qIVT7Zlv9epntU7"
app_secret = "OSTbxw28KcYm3QMLxXDrYvGNhmr87reSzdkJ52gtRIh5H8a075"
oauth_token = "1316287694746660864-JQZV77QzGz5Fa4Af5KMBM5RQms5FGk"
oauth_token_secret = "OsHT7xDK6E1tyi7mW8Naj3dUIpqfIKc6fl5hXM8lKtHcy"

twitter = Twython(app_key, app_secret, oauth_token, oauth_token_secret)

geocode="28.7041,77.1025,50mi" # latitude,longitude,distance(mi/km)

search_results=twitter.search(count=100, geocode=geocode, q="#covid19",since="2020-08-03") # query for scraping the tweets with hashtag covid19

try:
    for tweet in search_results['statuses']:
        print (tweet['text'])
except TwythonError as e:
    print(e)
# Out:
# RT @CBGAIndia: #COVID19
#
# An article by @KunduProtiva urges for immediate actions from the States and NGOs to rescue and rehabilitate #child…
# RT @drharshvardhan: #छत्तीसगढ़ में #कोविड19 की स्थिति व इससे निपटने के लिए उपयुक्त व्यवहार अपनाने को लेकर आज मैंने VC के माध्यम से राज्य के…
# RT @ndmaindia: #COVID19 | You can defeat #coronavirus by S.M.S!
#
# Let’s #Unite2FightCorona!💪 https://t.co/fYOCErmUM7
# Since air pollution is known to exacerbate respiratory diseases, which are majorly affected when an individual cont… https://t.co/e0mWtUwclR
# RT @raktnssdtu: #emergency #Delhincr
# Need #plasma from #COVID19 recovered patient.
#
# Patient's name: Ranpal Singh
# Age: 58 (M)
# Blood group: A…
# RT @Sunday_Standard: With the #coronavirus cases rising again, the Delhi government has decided to continue restrictions put on its expendi…
# RT @airnewsalerts: Bihar: #COVID19 recovery rate improves to 96.46 percent in state.
# RT @raktnssdtu: #emergency #Delhincr
# Need #plasma from #COVID19 recovered patient.
#
# Patient's name: Ranpal Singh
# Age: 58 (M)
# Blood group: A…
# Bihar: #COVID19 recovery rate improves to 96.46 percent in state.
# RT @ndmaindia: #COVID19 | You can defeat #coronavirus by S.M.S!
#
# Let’s #Unite2FightCorona!💪 https://t.co/fYOCErmUM7
# #COVID19 | You can defeat #coronavirus by S.M.S!
#
# Let’s #Unite2FightCorona!💪 https://t.co/fYOCErmUM7
# RT @ShahnawazBJP: Today, I got discharged from the #COVID19 ward of AIIMS.
#
# My sincere gratitude to all the doctors, nurses &amp; support staff…
# RT @ndmaindia: #COVID19 | Do you know how to boost your #immunity ?
#
# Here are some ways you can increase your immunity to #staysafe from #…
# RT @DelhiPolice: Popular Cricketer Yuvraj Singh  @YUVSTRONG12 urges all the citizens to take #Covid19 precautions during this Festive Seaso…
# RT @india_narrative: #Watch |
#
# UK Prime Minister #BorisJohnson wishes people ahead of the #Diwali festival
#
# He congratulates Hindus, Sikhs…
# RT @raktnssdtu: #emergency #Delhincr
# Need #plasma from #COVID19 recovered patient.
#
# Patient's name: Ranpal Singh
}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2374907317,
#      'id_str': '2374907317',
#      'indices': [3, 13],
#      'name': 'CBGA India',
#      'screen_name': 'CBGAIndia'},
#     {'id': 1295369607163699200,
#      'id_str': '1295369607163699200',
#      'indices': [39, 52],
#      'name': 'Protiva Kundu',
#      'screen_name': 'KunduProtiva'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325732095667343367,
#   'id_str': '1325732095667343367',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 06:31:09 +0000 2020',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1325687352660910081',
#       'indices': [117, 140],
#       'url': 'https://t.co/eqMVxPwm46'}],
#     'user_mentions': [{'id': 1295369607163699200,
#       'id_str': '1295369607163699200',
#       'indices': [24, 37],
#       'name': 'Protiva Kundu',
#       'screen_name': 'KunduProtiva'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1325687352660910081,
#    'id_str': '1325687352660910081',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': '#COVID19\n\nAn article by @KunduProtiva urges for immediate actions from the States and NGOs to rescue and rehabilita… https://t.co/eqMVxPwm46',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 06 06:04:18 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Centre for Budget and Governance Accountability is a think tank based in New Delhi that analyses public finances. Retweets/Likes are not endorsements.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'cbgaindia.org',
#         'expanded_url': 'http://www.cbgaindia.org',
#         'indices': [0, 23],
#         'url': 'https://t.co/aZL7zeLrtQ'}]}},
#     'favourites_count': 107,
#     'follow_request_sent': False,
#     'followers_count': 1460,
#     'following': False,
#     'friends_count': 97,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2374907317,
#     'id_str': '2374907317',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 28,
#     'location': 'New Delhi',
#     'name': 'CBGA India',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2374907317/1549882462',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/492547188023508992/mEdciB-M_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/492547188023508992/mEdciB-M_normal.png',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'CBGAIndia',
#     'statuses_count': 1489,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/aZL7zeLrtQ',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'RT @CBGAIndia: #COVID19\n\nAn article by @KunduProtiva urges for immediate actions from the States and NGOs to rescue and rehabilitate #child…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Nov 05 18:15:00 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Research from the Global South for Global Development. Network of 50+ think tanks from Asia, LatAm & Africa. Getting #SDGs to work. RT ≠ endorsement.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'southernvoice.org',
#        'expanded_url': 'http://southernvoice.org/',
#        'indices': [0, 23],
#        'url': 'https://t.co/1DqElJnHFv'}]}},
#    'favourites_count': 9585,
#    'follow_request_sent': False,
#    'followers_count': 3073,
#    'following': False,
#    'friends_count': 1803,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 2862946979,
#    'id_str': '2862946979',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 205,
#    'location': 'Global',
#    'name': 'Southern Voice',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2862946979/1544457424',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1072157150028402688/_WncolvZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1072157150028402688/_WncolvZ_normal.jpg',
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'SVoice2030',
#    'statuses_count': 15009,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/1DqElJnHFv',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:28:47 +0000 2020',
#   'entities': {'hashtags': [{'indices': [20, 30], 'text': 'छत्तीसगढ़'},
#     {'indices': [35, 43], 'text': 'कोविड19'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 77732185,
#      'id_str': '77732185',
#      'indices': [3, 18],
#      'name': 'Dr Harsh Vardhan',
#      'screen_name': 'drharshvardhan'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325732056119140358,
#   'id_str': '1325732056119140358',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'hi',
#   'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 75,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Nov 06 15:29:20 +0000 2020',
#    'entities': {'hashtags': [{'indices': [0, 10], 'text': 'छत्तीसगढ़'},
#      {'indices': [15, 23], 'text': 'कोविड19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1324735626839650304',
#       'indices': [115, 138],
#       'url': 'https://t.co/HKIfLizDOI'}],
#     'user_mentions': []},
#    'favorite_count': 508,
#    'favorited': False,
#    'geo': None,
#    'id': 1324735626839650304,
#    'id_str': '1324735626839650304',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'hi',
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 75,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': '#छत्तीसगढ़ में #कोविड19 की स्थिति व इससे निपटने के लिए उपयुक्त व्यवहार अपनाने को लेकर आज मैंने VC के माध्यम से रा… https://t.co/HKIfLizDOI',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Sep 27 13:11:01 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Union Minister for Health & Family Welfare, Science & Tech, Earth Sciences, Govt of India. ENT Surgeon. Chairman, Exec Board, WHO. Author - A Tale Of Two Drops.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'drharshvardhan.com',
#         'expanded_url': 'http://www.drharshvardhan.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/NEaNMed74Q'}]}},
#     'favourites_count': 4218,
#     'follow_request_sent': False,
#     'followers_count': 2603371,
#     'following': False,
#     'friends_count': 675,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 77732185,
#     'id_str': '77732185',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 1555,
#     'location': 'Delhi',
#     'name': 'Dr Harsh Vardhan',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/77732185/1599853349',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1312896044217241600/iy6G4n1B_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1312896044217241600/iy6G4n1B_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'drharshvardhan',
#     'statuses_count': 27261,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/NEaNMed74Q',
#     'utc_offset': None,
#     'verified': True}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'RT @drharshvardhan: #छत्तीसगढ़ में #कोविड19 की स्थिति व इससे निपटने के लिए उपयुक्त व्यवहार अपनाने को लेकर आज मैंने VC के माध्यम से राज्य के…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 19 08:36:00 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Trip For Care provides economically priced wellness and medical tourism services at affordable rates.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'tripforcare.com',
#        'expanded_url': 'http://tripforcare.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/ZYIRmzWdas'}]}},
#    'favourites_count': 7,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 20,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1296002830214377472,
#    'id_str': '1296002830214377472',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'India',
#    'name': 'TripForCare',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1296002830214377472/1597826317',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1296003077976109056/IB1YI1jF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296003077976109056/IB1YI1jF_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TripForCares',
#    'statuses_count': 31,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/ZYIRmzWdas',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:28:36 +0000 2020',
#   'entities': {'hashtags': [{'indices': [15, 23], 'text': 'COVID19'},
#     {'indices': [41, 53], 'text': 'coronavirus'},
#     {'indices': [72, 90], 'text': 'Unite2FightCorona'}],
#    'media': [{'display_url': 'pic.twitter.com/fYOCErmUM7',
#      'expanded_url': 'https://twitter.com/ndmaindia/status/1325731465397641217/photo/1',
#      'id': 1325730941633884160,
#      'id_str': '1325730941633884160',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#      'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 1600},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1325731465397641217,
#      'source_status_id_str': '1325731465397641217',
#      'source_user_id': 2611134289,
#      'source_user_id_str': '2611134289',
#      'type': 'photo',
#      'url': 'https://t.co/fYOCErmUM7'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 2611134289,
#      'id_str': '2611134289',
#      'indices': [3, 13],
#      'name': 'NDMA India | राष्ट्रीय आपदा प्रबंधन प्राधिकरण 🇮🇳',
#      'screen_name': 'ndmaindia'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/fYOCErmUM7',
#      'expanded_url': 'https://twitter.com/ndmaindia/status/1325731465397641217/photo/1',
#      'id': 1325730941633884160,
#      'id_str': '1325730941633884160',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#      'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 1600},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1325731465397641217,
#      'source_status_id_str': '1325731465397641217',
#      'source_user_id': 2611134289,
#      'source_user_id_str': '2611134289',
#      'type': 'photo',
#      'url': 'https://t.co/fYOCErmUM7'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325732010506162177,
#   'id_str': '1325732010506162177',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 09:26:26 +0000 2020',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'COVID19'},
#      {'indices': [26, 38], 'text': 'coronavirus'},
#      {'indices': [57, 75], 'text': 'Unite2FightCorona'}],
#     'media': [{'display_url': 'pic.twitter.com/fYOCErmUM7',
#       'expanded_url': 'https://twitter.com/ndmaindia/status/1325731465397641217/photo/1',
#       'id': 1325730941633884160,
#       'id_str': '1325730941633884160',
#       'indices': [78, 101],
#       'media_url': 'http://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#       'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 1600},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/fYOCErmUM7'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/fYOCErmUM7',
#       'expanded_url': 'https://twitter.com/ndmaindia/status/1325731465397641217/photo/1',
#       'id': 1325730941633884160,
#       'id_str': '1325730941633884160',
#       'indices': [78, 101],
#       'media_url': 'http://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmXxRHPU8AAuE7x.jpg',
#       'sizes': {'large': {'h': 900, 'resize': 'fit', 'w': 1600},
#        'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 383, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/fYOCErmUM7'}]},
#    'favorite_count': 5,
#    'favorited': False,
#    'geo': None,
#    'id': 1325731465397641217,
#    'id_str': '1325731465397641217',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': '#COVID19 | You can defeat #coronavirus by S.M.S! \n\nLet’s #Unite2FightCorona!💪 https://t.co/fYOCErmUM7',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jul 08 05:49:19 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'राष्ट्रीय आपदा प्रबंधन प्राधिकरण, भारत सरकार\xa0\nNational Disaster Management Authority, Govt of India',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'ndma.gov.in',
#         'expanded_url': 'http://ndma.gov.in',
#         'indices': [0, 22],
#         'url': 'http://t.co/f9Cwh6BXkV'}]}},
#     'favourites_count': 605,
#     'follow_request_sent': False,
#     'followers_count': 228350,
#     'following': False,
#     'friends_count': 3156,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2611134289,
#     'id_str': '2611134289',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 399,
#     'location': 'New Delhi-110029',
#     'name': 'NDMA India | राष्ट्रीय आपदा प्रबंधन प्राधिकरण 🇮🇳',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2611134289/1597991206',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/486388520995397633/0SdnJoio_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/486388520995397633/0SdnJoio_normal.png',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ndmaindia',
#     'statuses_count': 35480,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/f9Cwh6BXkV',
#     'utc_offset': None,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @ndmaindia: #COVID19 | You can defeat #coronavirus by S.M.S! \n\nLet’s #Unite2FightCorona!💪 https://t.co/fYOCErmUM7',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Apr 03 09:27:47 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'सबका साथ + सबका विकास + सबका विश्वास= विजयी भारत\nTY @NarendraModi @PiyushGoyal\n@OfficeOfRSP @Poonam_Mahajan fr follg\nYes V Can.Yes V R Doing It\nRTs≠Endorsements',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 140037,
#    'follow_request_sent': False,
#    'followers_count': 13419,
#    'following': False,
#    'friends_count': 4982,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 129145854,
#    'id_str': '129145854',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 85,
#    'location': '#VijayiBharat',
#    'name': '🇮🇳Arvind Joshi🇮🇳',
#    'notifications': False,
#    'profile_background_color': 'FFF04D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129145854/1527125761',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291256374337261568/iX-IFKhW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291256374337261568/iX-IFKhW_normal.jpg',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFF8AD',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'arvind_joshi',
#    'statuses_count': 207777,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:28:29 +0000 2020',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1325731977698271232',
#      'indices': [117, 140],
#      'url': 'https://t.co/e0mWtUwclR'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325731977698271232,
#   'id_str': '1325731977698271232',
#   'in_reply_to_screen_name': 'envecologic',
#   'in_reply_to_status_id': 1325731974913273856,
#   'in_reply_to_status_id_str': '1325731974913273856',
#   'in_reply_to_user_id': 634392625,
#   'in_reply_to_user_id_str': '634392625',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Since air pollution is known to exacerbate respiratory diseases, which are majorly affected when an individual cont… https://t.co/e0mWtUwclR',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jul 13 07:59:23 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'ENVECOLOGIC is a sustainability think-tank & capacity building firm. We focus on everything that impacts the 3Ps - People, Planet & Profit.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'envecologic.com',
#        'expanded_url': 'http://envecologic.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/UeaHxtxXXk'}]}},
#    'favourites_count': 621,
#    'follow_request_sent': False,
#    'followers_count': 1081,
#    'following': False,
#    'friends_count': 1450,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 634392625,
#    'id_str': '634392625',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 21,
#    'location': 'New Delhi, India',
#    'name': 'ENVECOLOGIC - Spearheading Sustainable Growth',
#    'notifications': False,
#    'profile_background_color': 'AEC26D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/634392625/1589616225',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1072425611405246464/6zDgLkFM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1072425611405246464/6zDgLkFM_normal.jpg',
#    'profile_link_color': 'D02B55',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'envecologic',
#    'statuses_count': 2940,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/UeaHxtxXXk',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:28:22 +0000 2020',
#   'entities': {'hashtags': [{'indices': [16, 26], 'text': 'emergency'},
#     {'indices': [27, 36], 'text': 'Delhincr'},
#     {'indices': [42, 49], 'text': 'plasma'},
#     {'indices': [55, 63], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1275021886049542145,
#      'id_str': '1275021886049542145',
#      'indices': [3, 14],
#      'name': 'RAKT',
#      'screen_name': 'raktnssdtu'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325731951039311872,
#   'id_str': '1325731951039311872',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 08:23:16 +0000 2020',
#    'entities': {'hashtags': [{'indices': [0, 10], 'text': 'emergency'},
#      {'indices': [11, 20], 'text': 'Delhincr'},
#      {'indices': [26, 33], 'text': 'plasma'},
#      {'indices': [39, 47], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1325715568641548288',
#       'indices': [116, 139],
#       'url': 'https://t.co/WSqRI24Ruc'}],
#     'user_mentions': []},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 1325715568641548288,
#    'id_str': '1325715568641548288',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "#emergency #Delhincr\nNeed #plasma from #COVID19 recovered patient.\n\nPatient's name: Ranpal Singh\nAge: 58 (M)\nBlood… https://t.co/WSqRI24Ruc",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jun 22 11:05:41 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Official Twitter handle of RAKT\nAn initiative by @NSSDTU to connect voluntary blood donors with recipients.\n\n#BeARaktVeer',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 91,
#     'follow_request_sent': False,
#     'followers_count': 161,
#     'following': False,
#     'friends_count': 9,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1275021886049542145,
#     'id_str': '1275021886049542145',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'New Delhi, India',
#     'name': 'RAKT',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275021886049542145/1593796732',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1290318006841573383/45trQSeb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290318006841573383/45trQSeb_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'raktnssdtu',
#     'statuses_count': 556,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "RT @raktnssdtu: #emergency #Delhincr\nNeed #plasma from #COVID19 recovered patient.\n\nPatient's name: Ranpal Singh\nAge: 58 (M)\nBlood group: A…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 20 13:42:15 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'DTU 2023\nVolunteer at @raktnssdtu',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 143,
#    'follow_request_sent': False,
#    'followers_count': 14,
#    'following': False,
#    'friends_count': 28,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1274336671446601728,
#    'id_str': '1274336671446601728',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': '',
#    'name': 'Piyush Kashyap',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1277858330220720129/G9Ue1l8M_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277858330220720129/G9Ue1l8M_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'PiyushK33144776',
#    'statuses_count': 383,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:28:03 +0000 2020',
#   'entities': {'hashtags': [{'indices': [30, 42], 'text': 'coronavirus'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 287587232,
#      'id_str': '287587232',
#      'indices': [3, 19],
#      'name': 'Sunday Standard',
#      'screen_name': 'Sunday_Standard'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325731870869393408,
#   'id_str': '1325731870869393408',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 09:13:01 +0000 2020',
#    'entities': {'hashtags': [{'indices': [9, 21], 'text': 'coronavirus'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1325728086395138048',
#       'indices': [117, 140],
#       'url': 'https://t.co/NmqyOtAvUz'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1325728086395138048,
#    'id_str': '1325728086395138048',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'text': 'With the #coronavirus cases rising again, the Delhi government has decided to continue restrictions put on its expe… https://t.co/NmqyOtAvUz',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Apr 25 08:48:43 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The definitive Sunday Newspaper from the New Indian Express group, published from New Delhi. Favours None. Fears None.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'thenewindianexpress.com/thesundaystand…',
#         'expanded_url': 'http://thenewindianexpress.com/thesundaystandard',
#         'indices': [0, 22],
#         'url': 'http://t.co/JyFZuSMVJd'}]}},
#     'favourites_count': 12,
#     'follow_request_sent': False,
#     'followers_count': 8164,
#     'following': False,
#     'friends_count': 146,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 287587232,
#     'id_str': '287587232',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 63,
#     'location': 'New Delhi',
#     'name': 'Sunday Standard',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/287587232/1549865632',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1324664123/profile-img_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1324664123/profile-img_normal.jpg',
#     'profile_link_color': '2FC2EF',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Sunday_Standard',
#     'statuses_count': 24025,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/JyFZuSMVJd',
#     'utc_offset': None,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @Sunday_Standard: With the #coronavirus cases rising again, the Delhi government has decided to continue restrictions put on its expendi…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 23 13:03:41 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Sr News Photographer at \nThe New Indian Express',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 12938,
#    'follow_request_sent': False,
#    'followers_count': 282,
#    'following': False,
#    'friends_count': 263,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 2583976046,
#    'id_str': '2583976046',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 2,
#    'location': 'Vijayawada, India',
#    'name': 'P Ravindra Babu_TNIE',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2583976046/1496073752',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1302236913043030016/cbz8X_x5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302236913043030016/cbz8X_x5_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'Ravindra_TNIE',
#    'statuses_count': 22498,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:27:44 +0000 2020',
#   'entities': {'hashtags': [{'indices': [26, 34], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1056850669,
#      'id_str': '1056850669',
#      'indices': [3, 17],
#      'name': 'All India Radio News',
#      'screen_name': 'airnewsalerts'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325731790896525312,
#   'id_str': '1325731790896525312',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 09:27:25 +0000 2020',
#    'entities': {'hashtags': [{'indices': [7, 15], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 12,
#    'favorited': False,
#    'geo': None,
#    'id': 1325731710160547840,
#    'id_str': '1325731710160547840',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Bihar: #COVID19 recovery rate improves to 96.46 percent in state.',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jan 03 04:15:45 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Official account of News Services Division, All India Radio.\n\nहिंदी के समाचारों के लिए @AIRNewsHindi को फॉलो करें!\nFollow @AIRNewsUrdu for news updates in Urdu',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 634,
#     'follow_request_sent': False,
#     'followers_count': 2562045,
#     'following': False,
#     'friends_count': 16,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1056850669,
#     'id_str': '1056850669',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 2716,
#     'location': 'New Delhi, India',
#     'name': 'All India Radio News',
#     'notifications': False,
#     'profile_background_color': '666655',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1056850669/1572580529',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245193871396671488/-JRWFczO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245193871396671488/-JRWFczO_normal.jpg',
#     'profile_link_color': '467895',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'airnewsalerts',
#     'statuses_count': 299733,
#     'time_zone': None,
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': None,
#     'verified': True}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'RT @airnewsalerts: Bihar: #COVID19 recovery rate improves to 96.46 percent in state.',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Sep 28 13:42:45 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Hi,\nif you see me, say Hi.\nHi.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8781,
#    'follow_request_sent': False,
#    'followers_count': 44,
#    'following': False,
#    'friends_count': 84,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1310575599975411715,
#    'id_str': '1310575599975411715',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'Kerala',
#    'name': 'vinyksr',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1310575599975411715/1602168351',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1319962081064484864/htmj1Tpi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319962081064484864/htmj1Tpi_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'vinyksr',
#    'statuses_count': 16469,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 09:27:34 +0000 2020',
#   'entities': {'hashtags': [{'indices': [16, 26], 'text': 'emergency'},
#     {'indices': [27, 36], 'text': 'Delhincr'},
#     {'indices': [42, 49], 'text': 'plasma'},
#     {'indices': [55, 63], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1275021886049542145,
#      'id_str': '1275021886049542145',
#      'indices': [3, 14],
#      'name': 'RAKT',
#      'screen_name': 'raktnssdtu'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325731747527454720,
#   'id_str': '1325731747527454720',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 11,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 08:23:16 +0000 2020',
#    'entities': {'hashtags': [{'indices': [0, 10], 'text': 'emergency'},
#      {'indices': [11, 20], 'text': 'Delhincr'},
#      {'indices': [26, 33], 'text': 'plasma'},
#      {'indices': [39, 47], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1325715568641548288',
#       'indices': [116, 139],
#       'url': 'https://t.co/WSqRI24Ruc'}],
#     'user_mentions': []},
#    'favorite_count': 3,
#    'favorited': False,
#    'geo': None,
#    'id': 1325715568641548288,
#    'id_str': '1325715568641548288',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 11,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': "#emergency #Delhincr\nNeed #plasma from #COVID19 recovered patient.\n\nPatient's name: Ranpal Singh\nAge: 58 (M)\nBlood… https://t.co/WSqRI24Ruc",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jun 22 11:05:41 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Official Twitter handle of RAKT\nAn initiative by @NSSDTU to connect voluntary blood donors with recipients.\n\n#BeARaktVeer',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 91,
#     'follow_request_sent': False,
#     'followers_count': 161,
#     'following': False,
#     'friends_count': 9,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 1275021886049542145,
#     'id_str': '1275021886049542145',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'New Delhi, India',
#     'name': 'RAKT',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275021886049542145/1593796732',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1290318006841573383/45trQSeb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290318006841573383/45trQSeb_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'raktnssdtu',
#     'statuses_count': 556,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': "RT @raktnssdtu: #emergency #Delhincr\nNeed #plasma from #COVID19 recovered patient.\n\nPatient's name: Ranpal Singh\nAge: 58 (M)\nBlood group: A…",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Nov 18 16:20:10 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 21325,
#    'follow_request_sent': False,
#    'followers_count': 136,
#    'following': False,
#    'friends_count': 1086,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 4280470154,
#    'id_str': '4280470154',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 1,
#    'location': 'India',
#    'name': 'Rahul Amin🇮🇳',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4280470154/1455169823',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1251924384253542400/Qt8FU3Qz_normal.jpg',
# ...
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TUCIOfficial',
#    'statuses_count': 14173,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/aWcc7yxvnl',
#    'utc_offset': None,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 08:56:31 +0000 2020',
#   'entities': {'hashtags': [{'indices': [0, 8], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1325723936349368322',
#      'indices': [121, 144],
#      'url': 'https://t.co/0OGPB26v71'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325723936349368322,
#   'id_str': '1325723936349368322',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': '#COVID19 is part of a growing trend of emerging zoonotic diseases, as habitat loss &amp; wildlife exploitation reduce b… https://t.co/0OGPB26v71',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat May 11 09:29:47 +0000 2019',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Official account of TUCI | Retweets ≠ Endorsements',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'instagram.com/tradeunionindia',
#        'expanded_url': 'http://www.instagram.com/tradeunionindia',
#        'indices': [0, 23],
#        'url': 'https://t.co/aWcc7yxvnl'}]}},
#    'favourites_count': 90,
#    'follow_request_sent': False,
#    'followers_count': 111,
#    'following': False,
#    'friends_count': 25,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1127143755499225088,
#    'id_str': '1127143755499225088',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'New Delhi, India',
#    'name': 'TUCI',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1127143755499225088/1559388724',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1134775732196917248/xSQ_5d9J_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1134775732196917248/xSQ_5d9J_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TUCIOfficial',
#    'statuses_count': 14173,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/aWcc7yxvnl',
#    'utc_offset': None,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 08:56:14 +0000 2020',
#   'entities': {'hashtags': [{'indices': [96, 104], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 245687754,
#      'id_str': '245687754',
#      'indices': [3, 12],
#      'name': 'Press Trust of India',
#      'screen_name': 'PTI_News'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325723862663720963,
#   'id_str': '1325723862663720963',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 8,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Nov 09 08:18:16 +0000 2020',
#    'entities': {'hashtags': [{'indices': [82, 90], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1325714310325129218',
#       'indices': [117, 140],
#       'url': 'https://t.co/TGYn9r4Gq7'}],
#     'user_mentions': []},
#    'favorite_count': 115,
#    'favorited': False,
#    'geo': None,
#    'id': 1325714310325129218,
#    'id_str': '1325714310325129218',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 8,
#    'retweeted': False,
#    'source': '<a href="http://www.ptinews.com" rel="nofollow">PTI_Tweets</a>',
#    'text': 'Six more people, including two Border Security Force personnel, test positive for #COVID19 in Mizoram; infection ta… https://t.co/TGYn9r4Gq7',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Feb 01 07:31:18 +0000 2011',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'PTI !  We bring the World to you...',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'ptinews.com',
#         'expanded_url': 'http://www.ptinews.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/lFLnN461pN'}]}},
#     'favourites_count': 0,
#     'follow_request_sent': False,
#     'followers_count': 3042857,
#     'following': False,
#     'friends_count': 1,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 245687754,
#     'id_str': '245687754',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 3802,
#     'location': 'New Delhi, India',
#     'name': 'Press Trust of India',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/826806758513446913/2__zaKJN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826806758513446913/2__zaKJN_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'PTI_News',
#     'statuses_count': 91466,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/lFLnN461pN',
#     'utc_offset': None,
#     'verified': True}},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'RT @PTI_News: Six more people, including two Border Security Force personnel, test positive for #COVID19 in Mizoram; infection tally rises…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 21 02:27:42 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 39,
#    'follow_request_sent': False,
#    'followers_count': 14,
#    'following': False,
#    'friends_count': 260,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2579672941,
#    'id_str': '2579672941',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': '',
#    'name': 'anoop kumar',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1065717502871777281/bCi9RwgF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1065717502871777281/bCi9RwgF_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'anoopkr75',
#    'statuses_count': 216,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 08:56:06 +0000 2020',
#   'entities': {'hashtags': [{'indices': [0, 6], 'text': 'india'},
#     {'indices': [7, 21], 'text': 'thepolicygram'},
#     {'indices': [22, 35], 'text': 'publicpolicy'},
#     {'indices': [36, 43], 'text': 'policy'},
#     {'indices': [44, 57], 'text': 'policyreform'},
#     {'indices': [58, 79], 'text': 'publicpolicyanalysis'},
#     {'indices': [80, 91], 'text': 'healthcare'},
#     {'indices': [92, 109], 'text': 'indianhealthcare'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1325723828404838400',
#      'indices': [111, 134],
#      'url': 'https://t.co/9ClB7jZUDR'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325723828404838400,
#   'id_str': '1325723828404838400',
#   'in_reply_to_screen_name': 'thepolicygram',
#   'in_reply_to_status_id': 1325723822448840712,
#   'in_reply_to_status_id_str': '1325723822448840712',
#   'in_reply_to_user_id': 1287649202588151808,
#   'in_reply_to_user_id_str': '1287649202588151808',
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': '#india #thepolicygram #publicpolicy #policy #policyreform #publicpolicyanalysis #healthcare #indianhealthcare… https://t.co/9ClB7jZUDR',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 27 07:21:16 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'A knowledge platform dedicated to the cause of Public Policy and furthering its understanding, accessibility and engagement amongst ordinary Indians.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'publicpolicyindia.com',
#        'expanded_url': 'http://publicpolicyindia.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/JIcy2cUVlY'}]}},
#    'favourites_count': 6,
#    'follow_request_sent': False,
#    'followers_count': 85,
#    'following': False,
#    'friends_count': 0,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1287649202588151808,
#    'id_str': '1287649202588151808',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 2,
#    'location': 'New Delhi',
#    'name': 'The PolicyGram',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1287649202588151808/1596010930',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1294599659470467073/mryb-AOx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294599659470467073/mryb-AOx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thepolicygram',
#    'statuses_count': 231,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/JIcy2cUVlY',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Nov 09 08:56:04 +0000 2020',
#   'entities': {'hashtags': [{'indices': [0, 6], 'text': 'india'},
#     {'indices': [7, 21], 'text': 'thepolicygram'},
#     {'indices': [22, 35], 'text': 'publicpolicy'},
#     {'indices': [36, 43], 'text': 'policy'},
#     {'indices': [44, 57], 'text': 'policyreform'},
#     {'indices': [58, 79], 'text': 'publicpolicyanalysis'},
#     {'indices': [80, 91], 'text': 'healthcare'},
#     {'indices': [92, 109], 'text': 'indianhealthcare'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1325723822448840712',
#      'indices': [111, 134],
#      'url': 'https://t.co/L3FClHkHtr'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1325723822448840712,
#   'id_str': '1325723822448840712',
#   'in_reply_to_screen_name': 'thepolicygram',
#   'in_reply_to_status_id': 1325723816656572416,
#   'in_reply_to_status_id_str': '1325723816656572416',
#   'in_reply_to_user_id': 1287649202588151808,
#   'in_reply_to_user_id_str': '1287649202588151808',
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': '#india #thepolicygram #publicpolicy #policy #policyreform #publicpolicyanalysis #healthcare #indianhealthcare… https://t.co/L3FClHkHtr',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jul 27 07:21:16 +0000 2020',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'A knowledge platform dedicated to the cause of Public Policy and furthering its understanding, accessibility and engagement amongst ordinary Indians.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'publicpolicyindia.com',
#        'expanded_url': 'http://publicpolicyindia.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/JIcy2cUVlY'}]}},
#    'favourites_count': 6,
#    'follow_request_sent': False,
#    'followers_count': 85,
#    'following': False,
#    'friends_count': 0,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 1287649202588151808,
#    'id_str': '1287649202588151808',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 2,
#    'location': 'New Delhi',
#    'name': 'The PolicyGram',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1287649202588151808/1596010930',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1294599659470467073/mryb-AOx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294599659470467073/mryb-AOx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'thepolicygram',
#    'statuses_count': 231,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/JIcy2cUVlY',
#    'utc_offset': None,
#    'verified': False}}]

# %%
users=[]
date=[]
texts=[]
fc=[]
pc=[]
for i in range(0,len(search_results['statuses'])):
  users.append(search_results['statuses'][i]['user']['name'])
  date.append(search_results['statuses'][i]['created_at'])
  texts.append(search_results['statuses'][i]['text'])
  fc.append(search_results['statuses'][i]['favorite_count'])
  pc.append(search_results['statuses'][i]['user']['location'])

# %%
data_new = {'User Name':  users,
            'Date of Tweet':date,
            'Text':texts,
            'Favourite Count':fc,
            'Location':pc
        }

# %%
import pandas as pd
df_new = pd.DataFrame (data_new, columns = ['User Name','Date of Tweet','Text','Favourite Count','Location'])

# %%
df_new
# Out:
#                                         User Name  ...          Location
# 0                                  Southern Voice  ...            Global
# 1                                     TripForCare  ...             India
# 2                                🇮🇳Arvind Joshi🇮🇳  ...     #VijayiBharat
# 3   ENVECOLOGIC - Spearheading Sustainable Growth  ...  New Delhi, India
# 4                                  Piyush Kashyap  ...
# ..                                            ...  ...               ...
# 95                                           TUCI  ...  New Delhi, India
# 96                                           TUCI  ...  New Delhi, India
# 97                                    anoop kumar  ...
# 98                                 The PolicyGram  ...         New Delhi
# 99                                 The PolicyGram  ...         New Delhi
#
# [100 rows x 5 columns]

# %%
df_new.shape
# Out:
# (100, 5)

# %%
from google.colab import files  # Converting the dataset to csv format
df_new.to_csv('filename.csv') 
files.download('filename.csv')

# %%
df=pd.read_csv("filename.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  ...          Location
# 0           0  ...            Global
# 1           1  ...             India
# 2           2  ...     #VijayiBharat
# 3           3  ...  New Delhi, India
# 4           4  ...               NaN
#
# [5 rows x 6 columns]
